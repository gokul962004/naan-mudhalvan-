# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import cv2
from glob import glob
from tqdm.notebook import tqdm
from PIL import Image
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.models import Sequential
from keras.utils import to_categorical
from keras.preprocessing.image import load_img
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Load the model

# %%
train_dir = "/kaggle/input/facial-expression-dataset/train/train"
test_dir = "/kaggle/input/facial-expression-dataset/test/test"

# %%
def load_dataset(directory):
    image_paths = []
    labels = []
    
    for label in os.listdir(directory):
        for filename in os.listdir(os.path.join(directory,label)):
            image_path=os.path.join(directory,label,filename)
            image_paths.append(image_path)
            labels.append(label)
        print(label,'completed')
    return image_paths, labels

# %%
# convert into dataframe
train = pd.DataFrame()
train['image'], train['label'] = load_dataset(train_dir)
train = train.sample(frac=1).reset_index(drop=True)
train.head()
# Out:
# surprise completed
# fear completed
# angry completed
# neutral completed
# sad completed
# disgust completed
# happy completed
#                                                image    label
# 0  /kaggle/input/facial-expression-dataset/train/...  disgust
# 1  /kaggle/input/facial-expression-dataset/train/...    happy
# 2  /kaggle/input/facial-expression-dataset/train/...  neutral
# 3  /kaggle/input/facial-expression-dataset/train/...    happy
# 4  /kaggle/input/facial-expression-dataset/train/...      sad

# %%
test = pd.DataFrame()
test['image'], test['label']= load_dataset(test_dir)
test.head()
# Out:
# surprise completed
# fear completed
# angry completed
# neutral completed
# sad completed
# disgust completed
# happy completed
#                                                image     label
# 0  /kaggle/input/facial-expression-dataset/test/t...  surprise
# 1  /kaggle/input/facial-expression-dataset/test/t...  surprise
# 2  /kaggle/input/facial-expression-dataset/test/t...  surprise
# 3  /kaggle/input/facial-expression-dataset/test/t...  surprise
# 4  /kaggle/input/facial-expression-dataset/test/t...  surprise

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(data=train, x='label')
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
from PIL import Image
image = Image.open(train['image'][0])
plt.imshow(image, cmap='gray');

# %%
plt.figure(figsize=(20,20))
files = train.iloc[0:25]

for index, file, label in files.itertuples():
    plt.subplot(5,5, index+1)
    img = load_img(file)
    img = np.array(img)
    plt.imshow(img)
    plt.title(label)
    plt.axis('off')

# %% [markdown]
# ## Feature Extraction

# %%
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image)
        img_array = np.array(img) / 255.0  # Normalize pixel values
        features.append(img_array)

    features = np.array(features)
    print("Original shape:", features.shape)

    try:
        features = features.reshape(len(features), 48, 48, 3)
        print("Reshaped successfully.")
    except ValueError as e:
        print(f"Error during reshape: {e}")

    return features

# %%
train_features = extract_features(train['image'])
# Out:
#   0%|          | 0/28709 [00:00<?, ?it/s]
# Original shape: (28709, 48, 48, 3)
# Reshaped successfully.

# %%
test_features = extract_features(test['image'])
# Out:
#   0%|          | 0/7178 [00:00<?, ?it/s]
# Original shape: (7178, 48, 48, 3)
# Reshaped successfully.

# %%
min_value = np.min(train_features)
max_value = np.max(train_features)

print(f"Minimum pixel value: {min_value}")
print(f"Maximum pixel value: {max_value}")
# Out:
# Minimum pixel value: 0.0
# Maximum pixel value: 1.0

# %%
min_value = np.min(test_features)
max_value = np.max(test_features)

print(f"Minimum pixel value: {min_value}")
print(f"Maximum pixel value: {max_value}")
# Out:
# Minimum pixel value: 0.0
# Maximum pixel value: 1.0

# %%
X_train = train_features
X_test = test_features

# %%
 ## convert label to integar
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(train['label'])

y_train = le.transform(train['label'])
y_test = le.transform(test['label'])

# %%
y_train = to_categorical(y_train,num_classes=7)
y_test = to_categorical(y_test,num_classes=7)

# %%
y_train[0]
# Out:
# array([0., 1., 0., 0., 0., 0., 0.], dtype=float32)

# %%
input_shape = (48,48,3)
output_class = 7

# %% [markdown]
# ## Model creation

# %%
model = Sequential()

# Convolutional block
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(output_class, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 128)       3584
#
#  max_pooling2d (MaxPooling2  (None, 23, 23, 128)       0
#  D)
#
#  dropout (Dropout)           (None, 23, 23, 128)       0
#
#  conv2d_1 (Conv2D)           (None, 21, 21, 256)       295168
#
#  max_pooling2d_1 (MaxPoolin  (None, 10, 10, 256)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 10, 10, 256)       0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 512)         1180160
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 512)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 512)         0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 512)         2359808
#
#  max_pooling2d_3 (MaxPoolin  (None, 1, 1, 512)         0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 4234503 (16.15 MB)
# Trainable params: 4234503 (16.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x=X_train, y=y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 2023-11-18 18:43:43.971697: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 449/449 [==============================] - 31s 31ms/step - loss: 1.8226 - accuracy: 0.2474 - val_loss: 1.8192 - val_accuracy: 0.2471
# Epoch 2/50
# 449/449 [==============================] - 12s 28ms/step - loss: 1.8139 - accuracy: 0.2513 - val_loss: 1.8154 - val_accuracy: 0.2471
# Epoch 3/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.8122 - accuracy: 0.2524 - val_loss: 1.8047 - val_accuracy: 0.2561
# Epoch 4/50
# 449/449 [==============================] - 12s 28ms/step - loss: 1.8010 - accuracy: 0.2550 - val_loss: 1.7933 - val_accuracy: 0.2524
# Epoch 5/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.7652 - accuracy: 0.2727 - val_loss: 1.6991 - val_accuracy: 0.3023
# Epoch 6/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.7112 - accuracy: 0.3051 - val_loss: 1.6178 - val_accuracy: 0.3480
# Epoch 7/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.6274 - accuracy: 0.3535 - val_loss: 1.5262 - val_accuracy: 0.4087
# Epoch 8/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.5634 - accuracy: 0.3864 - val_loss: 1.4373 - val_accuracy: 0.4342
# Epoch 9/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.5157 - accuracy: 0.4071 - val_loss: 1.4144 - val_accuracy: 0.4413
# Epoch 10/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.4886 - accuracy: 0.4215 - val_loss: 1.3736 - val_accuracy: 0.4589
# Epoch 11/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.4678 - accuracy: 0.4341 - val_loss: 1.3602 - val_accuracy: 0.4756
# Epoch 12/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.4443 - accuracy: 0.4446 - val_loss: 1.3498 - val_accuracy: 0.4781
# Epoch 13/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.4202 - accuracy: 0.4527 - val_loss: 1.3120 - val_accuracy: 0.4891
# Epoch 14/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.4091 - accuracy: 0.4586 - val_loss: 1.3153 - val_accuracy: 0.4861
# Epoch 15/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.3925 - accuracy: 0.4626 - val_loss: 1.3352 - val_accuracy: 0.4857
# Epoch 16/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.3807 - accuracy: 0.4684 - val_loss: 1.2737 - val_accuracy: 0.5064
# Epoch 17/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.3691 - accuracy: 0.4739 - val_loss: 1.2659 - val_accuracy: 0.5141
# Epoch 18/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.3577 - accuracy: 0.4806 - val_loss: 1.2596 - val_accuracy: 0.5137
# Epoch 19/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.3422 - accuracy: 0.4852 - val_loss: 1.2567 - val_accuracy: 0.5206
# Epoch 20/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.3378 - accuracy: 0.4852 - val_loss: 1.2481 - val_accuracy: 0.5245
# Epoch 21/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.3267 - accuracy: 0.4947 - val_loss: 1.2415 - val_accuracy: 0.5203
# Epoch 22/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.3222 - accuracy: 0.4976 - val_loss: 1.2285 - val_accuracy: 0.5297
# Epoch 23/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.3060 - accuracy: 0.5024 - val_loss: 1.2335 - val_accuracy: 0.5245
# Epoch 24/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.3012 - accuracy: 0.5032 - val_loss: 1.2047 - val_accuracy: 0.5380
# Epoch 25/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2880 - accuracy: 0.5109 - val_loss: 1.2151 - val_accuracy: 0.5309
# Epoch 26/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2807 - accuracy: 0.5141 - val_loss: 1.2397 - val_accuracy: 0.5276
# Epoch 27/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2840 - accuracy: 0.5122 - val_loss: 1.2158 - val_accuracy: 0.5408
# Epoch 28/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2705 - accuracy: 0.5176 - val_loss: 1.2721 - val_accuracy: 0.5177
# Epoch 29/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2659 - accuracy: 0.5202 - val_loss: 1.2242 - val_accuracy: 0.5320
# Epoch 30/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2629 - accuracy: 0.5205 - val_loss: 1.1853 - val_accuracy: 0.5478
# Epoch 31/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2535 - accuracy: 0.5287 - val_loss: 1.1674 - val_accuracy: 0.5568
# Epoch 32/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2535 - accuracy: 0.5230 - val_loss: 1.1949 - val_accuracy: 0.5449
# Epoch 33/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2419 - accuracy: 0.5306 - val_loss: 1.1667 - val_accuracy: 0.5571
# Epoch 34/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2402 - accuracy: 0.5318 - val_loss: 1.1711 - val_accuracy: 0.5541
# Epoch 35/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2363 - accuracy: 0.5319 - val_loss: 1.1786 - val_accuracy: 0.5518
# Epoch 36/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2357 - accuracy: 0.5334 - val_loss: 1.1670 - val_accuracy: 0.5541
# Epoch 37/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2316 - accuracy: 0.5378 - val_loss: 1.1902 - val_accuracy: 0.5451
# Epoch 38/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.2182 - accuracy: 0.5390 - val_loss: 1.1835 - val_accuracy: 0.5483
# Epoch 39/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2158 - accuracy: 0.5419 - val_loss: 1.1789 - val_accuracy: 0.5483
# Epoch 40/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2183 - accuracy: 0.5378 - val_loss: 1.1472 - val_accuracy: 0.5662
# Epoch 41/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2143 - accuracy: 0.5438 - val_loss: 1.1540 - val_accuracy: 0.5674
# Epoch 42/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2073 - accuracy: 0.5429 - val_loss: 1.1610 - val_accuracy: 0.5651
# Epoch 43/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2013 - accuracy: 0.5452 - val_loss: 1.1518 - val_accuracy: 0.5677
# Epoch 44/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.2012 - accuracy: 0.5468 - val_loss: 1.1461 - val_accuracy: 0.5637
# Epoch 45/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1978 - accuracy: 0.5497 - val_loss: 1.1486 - val_accuracy: 0.5660
# Epoch 46/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.1887 - accuracy: 0.5516 - val_loss: 1.1601 - val_accuracy: 0.5674
# Epoch 47/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.1890 - accuracy: 0.5522 - val_loss: 1.1511 - val_accuracy: 0.5651
# Epoch 48/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.1816 - accuracy: 0.5590 - val_loss: 1.1553 - val_accuracy: 0.5690
# Epoch 49/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.1864 - accuracy: 0.5533 - val_loss: 1.1396 - val_accuracy: 0.5642
# Epoch 50/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.1784 - accuracy: 0.5571 - val_loss: 1.1361 - val_accuracy: 0.5715

# %%
model.fit(x=X_train, y=y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 449/449 [==============================] - 13s 30ms/step - loss: 1.1693 - accuracy: 0.5605 - val_loss: 1.1258 - val_accuracy: 0.5762
# Epoch 2/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1772 - accuracy: 0.5610 - val_loss: 1.1287 - val_accuracy: 0.5786
# Epoch 3/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1624 - accuracy: 0.5646 - val_loss: 1.1474 - val_accuracy: 0.5676
# Epoch 4/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.1612 - accuracy: 0.5666 - val_loss: 1.1304 - val_accuracy: 0.5822
# Epoch 5/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.1587 - accuracy: 0.5649 - val_loss: 1.1264 - val_accuracy: 0.5769
# Epoch 6/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.1638 - accuracy: 0.5634 - val_loss: 1.1289 - val_accuracy: 0.5843
# Epoch 7/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1548 - accuracy: 0.5661 - val_loss: 1.1382 - val_accuracy: 0.5747
# Epoch 8/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1497 - accuracy: 0.5693 - val_loss: 1.1269 - val_accuracy: 0.5804
# Epoch 9/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1513 - accuracy: 0.5715 - val_loss: 1.1257 - val_accuracy: 0.5752
# Epoch 10/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1457 - accuracy: 0.5669 - val_loss: 1.1067 - val_accuracy: 0.5829
# Epoch 11/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1444 - accuracy: 0.5737 - val_loss: 1.1274 - val_accuracy: 0.5861
# Epoch 12/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1434 - accuracy: 0.5748 - val_loss: 1.1240 - val_accuracy: 0.5740
# Epoch 13/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.1329 - accuracy: 0.5755 - val_loss: 1.1220 - val_accuracy: 0.5755
# Epoch 14/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1335 - accuracy: 0.5742 - val_loss: 1.0962 - val_accuracy: 0.5950
# Epoch 15/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1349 - accuracy: 0.5761 - val_loss: 1.1265 - val_accuracy: 0.5756
# Epoch 16/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.1319 - accuracy: 0.5781 - val_loss: 1.1144 - val_accuracy: 0.5833
# Epoch 17/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1287 - accuracy: 0.5785 - val_loss: 1.1116 - val_accuracy: 0.5807
# Epoch 18/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.1196 - accuracy: 0.5835 - val_loss: 1.1099 - val_accuracy: 0.5871
# Epoch 19/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1261 - accuracy: 0.5790 - val_loss: 1.1069 - val_accuracy: 0.5867
# Epoch 20/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1150 - accuracy: 0.5799 - val_loss: 1.0981 - val_accuracy: 0.5906
# Epoch 21/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1107 - accuracy: 0.5856 - val_loss: 1.1244 - val_accuracy: 0.5768
# Epoch 22/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1170 - accuracy: 0.5853 - val_loss: 1.0964 - val_accuracy: 0.5903
# Epoch 23/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.1079 - accuracy: 0.5858 - val_loss: 1.1031 - val_accuracy: 0.5872
# Epoch 24/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.1018 - accuracy: 0.5894 - val_loss: 1.1195 - val_accuracy: 0.5815
# Epoch 25/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1033 - accuracy: 0.5885 - val_loss: 1.0973 - val_accuracy: 0.5874
# Epoch 26/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.0935 - accuracy: 0.5926 - val_loss: 1.0922 - val_accuracy: 0.5946
# Epoch 27/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.1005 - accuracy: 0.5889 - val_loss: 1.0973 - val_accuracy: 0.5928
# Epoch 28/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.0912 - accuracy: 0.5931 - val_loss: 1.1279 - val_accuracy: 0.5836
# Epoch 29/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0937 - accuracy: 0.5916 - val_loss: 1.1023 - val_accuracy: 0.5906
# Epoch 30/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0845 - accuracy: 0.5958 - val_loss: 1.0918 - val_accuracy: 0.5938
# Epoch 31/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0943 - accuracy: 0.5898 - val_loss: 1.0868 - val_accuracy: 0.5915
# Epoch 32/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.0810 - accuracy: 0.6003 - val_loss: 1.0971 - val_accuracy: 0.5919
# Epoch 33/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0822 - accuracy: 0.5995 - val_loss: 1.0864 - val_accuracy: 0.5925
# Epoch 34/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0827 - accuracy: 0.5987 - val_loss: 1.1073 - val_accuracy: 0.5896
# Epoch 35/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0725 - accuracy: 0.6021 - val_loss: 1.0838 - val_accuracy: 0.5925
# Epoch 36/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0766 - accuracy: 0.6014 - val_loss: 1.0875 - val_accuracy: 0.5992
# Epoch 37/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0798 - accuracy: 0.5993 - val_loss: 1.0884 - val_accuracy: 0.5914
# Epoch 38/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.0745 - accuracy: 0.6014 - val_loss: 1.0952 - val_accuracy: 0.5921
# Epoch 39/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0714 - accuracy: 0.6019 - val_loss: 1.0858 - val_accuracy: 0.5907
# Epoch 40/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0629 - accuracy: 0.6041 - val_loss: 1.0891 - val_accuracy: 0.5900
# Epoch 41/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0554 - accuracy: 0.6070 - val_loss: 1.0874 - val_accuracy: 0.5988
# Epoch 42/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0619 - accuracy: 0.6018 - val_loss: 1.0647 - val_accuracy: 0.6000
# Epoch 43/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.0602 - accuracy: 0.6095 - val_loss: 1.0887 - val_accuracy: 0.5940
# Epoch 44/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0527 - accuracy: 0.6040 - val_loss: 1.0880 - val_accuracy: 0.5952
# Epoch 45/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0548 - accuracy: 0.6075 - val_loss: 1.0956 - val_accuracy: 0.5890
# Epoch 46/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0522 - accuracy: 0.6107 - val_loss: 1.0970 - val_accuracy: 0.5968
# Epoch 47/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0554 - accuracy: 0.6098 - val_loss: 1.0976 - val_accuracy: 0.5936
# Epoch 48/50
# 449/449 [==============================] - 13s 28ms/step - loss: 1.0506 - accuracy: 0.6097 - val_loss: 1.0683 - val_accuracy: 0.5971
# Epoch 49/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0450 - accuracy: 0.6124 - val_loss: 1.0756 - val_accuracy: 0.5935
# Epoch 50/50
# 449/449 [==============================] - 13s 29ms/step - loss: 1.0543 - accuracy: 0.6111 - val_loss: 1.0772 - val_accuracy: 0.5992

# %%
history = model.fit(x=X_train, y=y_train, epochs=10, batch_size=128, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 225/225 [==============================] - 13s 53ms/step - loss: 1.0129 - accuracy: 0.6268 - val_loss: 1.0711 - val_accuracy: 0.6017
# Epoch 2/10
# 225/225 [==============================] - 11s 50ms/step - loss: 0.9962 - accuracy: 0.6300 - val_loss: 1.0653 - val_accuracy: 0.6013
# Epoch 3/10
# 225/225 [==============================] - 11s 50ms/step - loss: 0.9912 - accuracy: 0.6329 - val_loss: 1.0546 - val_accuracy: 0.6055
# Epoch 4/10
# 225/225 [==============================] - 11s 50ms/step - loss: 0.9849 - accuracy: 0.6331 - val_loss: 1.0566 - val_accuracy: 0.6035
# Epoch 5/10
# 225/225 [==============================] - 11s 50ms/step - loss: 0.9878 - accuracy: 0.6342 - val_loss: 1.0717 - val_accuracy: 0.6042
# Epoch 6/10
# 225/225 [==============================] - 11s 50ms/step - loss: 0.9699 - accuracy: 0.6423 - val_loss: 1.0596 - val_accuracy: 0.6034
# Epoch 7/10
# 225/225 [==============================] - 11s 50ms/step - loss: 0.9780 - accuracy: 0.6366 - val_loss: 1.0435 - val_accuracy: 0.6096
# Epoch 8/10
# 225/225 [==============================] - 11s 50ms/step - loss: 0.9727 - accuracy: 0.6424 - val_loss: 1.0539 - val_accuracy: 0.6049
# Epoch 9/10
# 225/225 [==============================] - 11s 50ms/step - loss: 0.9779 - accuracy: 0.6394 - val_loss: 1.0585 - val_accuracy: 0.6034
# Epoch 10/10
# 225/225 [==============================] - 11s 50ms/step - loss: 0.9714 - accuracy: 0.6416 - val_loss: 1.0541 - val_accuracy: 0.6060

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range((len(acc)))

plt.plot(epochs,acc,'b',label='Training Accuracy')
plt.plot(epochs, val_acc,'r',label='Validation Accuracy')
plt.title("Accuracy Graph")
plt.legend()
plt.figure()

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs,loss,'b',label='Training loss')
plt.plot(epochs, val_loss,'r',label='Validation loss')
plt.title("Loss Graph")
plt.legend()
plt.figure()
plt.show()

# %% [markdown]
# ## Test with image data

# %%
import random

image_index = random.randint(0, len(test))
print("original output:", test['label'][image_index])
pred = model.predict(X_test[image_index].reshape(1, 48, 48, 3))
prediction_label = le.inverse_transform([pred.argmax()])[0]
print("Prediction output:", prediction_label)
plt.imshow(X_test[image_index].reshape(48, 48, 3), cmap='gray')
plt.show()
# Out:
# original output: surprise
# 1/1 [==============================] - 0s 353ms/step
# Prediction output: surprise

# %%
image_index = random.randint(0, len(test))
print("original output:", test['label'][image_index])
pred = model.predict(X_test[image_index].reshape(1, 48, 48, 3))
prediction_label = le.inverse_transform([pred.argmax()])[0]
print("Prediction output:", prediction_label)
plt.imshow(X_test[image_index].reshape(48, 48, 3), cmap='viridis')  
plt.show()
# Out:
# original output: happy
# 1/1 [==============================] - 0s 21ms/step
# Prediction output: happy

# %%
image_index = random.randint(0, len(test))
print("original output:", test['label'][image_index])
pred = model.predict(X_test[image_index].reshape(1, 48, 48, 3))
prediction_label = le.inverse_transform([pred.argmax()])[0]
print("Prediction output:", prediction_label)
plt.imshow(X_test[image_index].reshape(48, 48, 3), cmap='gray')  
plt.show()
# Out:
# original output: sad
# 1/1 [==============================] - 0s 20ms/step
# Prediction output: sad

# %%
image_index = random.randint(0, len(test))
print("original output:", test['label'][image_index])
pred = model.predict(X_test[image_index].reshape(1, 48, 48, 3))
prediction_label = le.inverse_transform([pred.argmax()])[0]
print("Prediction output:", prediction_label)
plt.imshow(X_test[image_index].reshape(48, 48, 3), cmap='viridis')  
plt.show()
# Out:
# original output: surprise
# 1/1 [==============================] - 0s 19ms/step
# Prediction output: surprise
